# %%
import pandas as pd

# %%
jobs = pd.read_csv('C:/Users/abc/Downloads/new_jobs.csv')
details = pd.read_csv('C:/Users/abc/Downloads/new_details.csv')
company = pd.read_csv('C:/Users/abc/Downloads/new_company.csv')

# %%
jobs
# Out:
#                                                  job_id  company_id  \
# 0                                          070923501018       19589
# 1     270523906122?src=jobsearchDesk&sid=16941696232...        7682
# 2                                          230920500882     4571516
# 3                                          210123500752     1295512
# 4                                          180722500200     1295512
# ...                                                 ...         ...
# 1975                                       060923910646        7682
# 1976                                       060923910639        7682
# 1977                                       060923910635        7682
# 1978                                       060923910627        7682
# 1979                                       060923910626        7682
#
#                                                location  \
# 0     Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# ...

# %%
jobs['location'] = jobs['location'].str.split(', ')

jobs = jobs.explode('location').reset_index(drop=True)

# Print the resulting DataFrame
jobs
# Out:
#             job_id  company_id                location  \
# 0     070923501018       19589                 Kolkata
# 1     070923501018       19589                  Mumbai
# 2     070923501018       19589               New Delhi
# 3     070923501018       19589  Hyderabad/Secunderabad
# 4     070923501018       19589                    Pune
# ...            ...         ...                     ...
# 6864  060923910646        7682     Bangalore/Bengaluru
# 6865  060923910639        7682     Bangalore/Bengaluru
# 6866  060923910635        7682     Bangalore/Bengaluru
# 6867  060923910627        7682     Bangalore/Bengaluru
# 6868  060923910626        7682     Bangalore/Bengaluru
#
#                                             designation  details_id
# 0                      Associate - Inventory Accounting           0
# 1                      Associate - Inventory Accounting           0
# 2                      Associate - Inventory Accounting           0
# ...

# %%
jobs['job_id'] = jobs['job_id'].replace('270523906122?src=jobsearchDesk&sid=1694169623207455&xp=2&px=1','270523906122')

# %%
jobs['location'] = jobs['location'].replace('Hyderabad/Secunderabad','Hyderabad')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru','Bangalore')
jobs['location'] = jobs['location'].replace('Mumbai (All Areas)','Mumbai')
jobs['location'] = jobs['location'].replace('Hybrid - Kolkata','Kolkata')
jobs['location'] = jobs['location'].replace('Delhi / NCR','Delhi')
jobs['location'] = jobs['location'].replace('Gurgaon/Gurugram','Gurgaon')
jobs['location'] = jobs['location'].replace('Hybrid - Mumbai','Mumbai')
jobs['location'] = jobs['location'].replace('Hybrid - Noida','Noida')
jobs['location'] = jobs['location'].replace('Hybrid - Hyderabad/ Secunderabad','Hyderabad')
jobs['location'] = jobs['location'].replace('Kochi/ Cochin','Kochi')
jobs['location'] = jobs['location'].replace('Hybrid - Pune','Pune')
jobs['location'] = jobs['location'].replace('Allahabad/ Prayagraj','Allahabad')
jobs['location'] = jobs['location'].replace('Calicut/ Kozhikode','Kozhikode')
jobs['location'] = jobs['location'].replace('Hybrid - Hyderabad/Secunderabad','Hyderabad')
jobs['location'] = jobs['location'].replace('Hyderabad/Secunderabad(Uppal)','Hyderabad')
jobs['location'] = jobs['location'].replace('Hybrid - Kochi/ Cochin','Kochi')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Koramangala)','Bangalore')
jobs['location'] = jobs['location'].replace('Hyderabad/ Secunderabad','Hyderabad')
jobs['location'] = jobs['location'].replace('Bangalore/ Bengaluru','Bangalore')
jobs['location'] = jobs['location'].replace('Trivandrum/Thiruvananthapuram','Trivandrum')
jobs['location'] = jobs['location'].replace('Gurgaon/ Gurugram','Gurgaon')

# %%
jobs['location'] = jobs['location'].replace('Kalyan/ Dombivli','Kalyan')
jobs['location'] = jobs['location'].replace('Mangaluru/Mangalore','Mangalore')
jobs['location'] = jobs['location'].replace('Vadodara/ Baroda','Vadodara')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Kengeri Satellite Town Stage 1 +1070)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Mumbai Suburban','Mumbai')
jobs['location'] = jobs['location'].replace('Hybrid - Bhubaneswar','Bhubaneswar')
jobs['location'] = jobs['location'].replace('Hybrid - Indore','Indore')
jobs['location'] = jobs['location'].replace('Kochi/Cochin','Kochi')
jobs['location'] = jobs['location'].replace('Hybrid - Visakhapatnam/ Vizag','Visakhapatnam')
jobs['location'] = jobs['location'].replace('Visakhapatnam/ Vizag','Visakhapatnam')
jobs['location'] = jobs['location'].replace('Mysore/ Mysuru','Mysore')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/Bengaluru','Bangalore')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Bellandur)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/ Bengaluru','Bangalore')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Electronic City +6)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Kochi/Cochin','Kochi')
jobs['location'] = jobs['location'].replace('Nasik/ Nashik','Nashik')
jobs['location'] = jobs['location'].replace('Nasik/Nashik','Nashik')
jobs['location'] = jobs['location'].replace('Trivandrum/ Thiruvananthapuram','Trivandrum')
jobs['location'] = jobs['location'].replace('Maharashtra(Pune Nashik Highway)','Pune')
jobs['location'] = jobs['location'].replace('Karnataka(Hoskote)','Karnataka')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Kengeri Satellite Town Stage 1 +489)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Chennai','Chennai')
jobs['location'] = jobs['location'].replace('Karnataka(Bellandur)','Bellandur')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(HSR Layout)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/ Bengaluru','Bangalore')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Electronic City +6)','Bangalore')
jobs['location'] = jobs['location'].replace('Maharashtra(Wadala)','Wadala')
jobs['location'] = jobs['location'].replace('Hybrid - Gurgaon/ Gurugram','Gurgaon')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Hosur Road +1)','Bangalore')
jobs['location'] = jobs['location'].replace('Gulbarga/ Kalburagi','Gulbarga')
jobs['location'] = jobs['location'].replace('Karnataka(Lalbagh Road)','Karnataka')
jobs['location'] = jobs['location'].replace('Karnataka(HSR Layout)','Karnataka')
jobs['location'] = jobs['location'].replace('Other Cities- India','Other Cities')
jobs['location'] = jobs['location'].replace('Hybrid - Coimbatore','Coimbatore')
jobs['location'] = jobs['location'].replace('Karnataka(Sarjapur +3)','Karnataka')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/Bengaluru(Kadugodi +1)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore Rural','Bangalore')
jobs['location'] = jobs['location'].replace('Karnataka(Hennur)','Karnataka')
jobs['location'] = jobs['location'].replace('Bangalore/Bengaluru(Halasur)','Bangalore')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/Bengaluru(Richmond Road)','Bangalore')
jobs['location'] = jobs['location'].replace('Karnataka(Marathahalli)','Karnataka')
jobs['location'] = jobs['location'].replace('Hybrid - Bangalore/Bengaluru(Bellandur)','Bangalore')

# %%
jobs['location'].unique()
# Out:
# array(['Kolkata', 'Mumbai', 'New Delhi', 'Hyderabad', 'Pune', 'Chennai',
#        'Bangalore', 'West Bengal', 'Maharashtra', 'Telangana', 'Gurgaon',
#        'Tamil Nadu', 'Delhi', 'Ahmedabad', 'Haryana', 'Karnataka',
#        'Noida', 'Chandigarh', 'Indore', 'Jaipur', 'Trivandrum',
#        'Uttar Pradesh', 'Kharagpur', 'Udaipur', 'Rajasthan',
#        'Location not found', 'Coimbatore', 'Gandhinagar', 'Gujarat',
#        'Bangalore Rural', 'Rohtak', 'Allahabad', 'Jhansi', 'Bhagalpur',
#        'Bihar', 'Kozhikode', 'Kerala', 'Vadodara', 'Navi Mumbai', 'Ajmer',
#        'Mumbai Suburban', 'Kochi', 'Madhya Pradesh', 'Greater Noida',
#        'Visakhapatnam', 'india', 'Vijayawada', 'Andhra Pradesh', 'Nagpur',
#        'Ghaziabad', 'Kalyan', 'Aurangabad', 'Mangalore', 'Gandhidham',
#        'Surat', 'Bhubaneswar', 'Odisha', 'Thane', 'Lucknow', 'Kottayam',
#        'Mysore', 'Remote', 'Guwahati', 'Assam', 'Tirupati', 'Ernakulam',
# ...

# %%
bang =  ['Bangalore/Bengaluru(Electronic City)','Bangalore/Bengaluru(Rajaji Nagar +1)','Bangalore/Bengaluru(Hebbal)',
        'Bangalore/Bengaluru(Domlur)','Bangalore/Bengaluru(Hebbal Kempapura +1)']

# %%
for i in jobs['location']:
    if i in bang :
        jobs['location'] = jobs['location'].replace(i,'Bangalore')

# %%
jobs['location'] = jobs['location'].replace('Karnataka(Whitefield +3)','Karnataka')

# %%
jobs.isna().sum()
# Out:
# job_id         0
# company_id     0
# location       0
# designation    0
# details_id     0
# dtype: int64

# %%
jobs.drop_duplicates(inplace = True)

# %%
sum(jobs.duplicated())
# Out:
# 0

# %%
jobs
# Out:
#             job_id  company_id   location  \
# 0     070923501018       19589    Kolkata
# 1     070923501018       19589     Mumbai
# 2     070923501018       19589  New Delhi
# 3     070923501018       19589  Hyderabad
# 4     070923501018       19589       Pune
# ...            ...         ...        ...
# 6864  060923910646        7682  Bangalore
# 6865  060923910639        7682  Bangalore
# 6866  060923910635        7682  Bangalore
# 6867  060923910627        7682  Bangalore
# 6868  060923910626        7682  Bangalore
#
#                                             designation  details_id
# 0                      Associate - Inventory Accounting           0
# 1                      Associate - Inventory Accounting           0
# 2                      Associate - Inventory Accounting           0
# 3                      Associate - Inventory Accounting           0
# 4                      Associate - Inventory Accounting           0
# ...

# %%
details
# Out:
#       details_id                                 Role:  \
# 0              0                     Finance Executive
# 2              2                    Back End Developer
# 3              3  Business Development Executive (BDE)
# 4              4                      Customer Service
# 5              5          Software Development - Other
# ...          ...                                   ...
# 1949        1949                    Back End Developer
# 1951        1951                Database Administrator
# 1958        1958                    Back End Developer
# 1959        1959                  Maintenance Engineer
# 1960        1960                  Radiologist - Doctor
#
#                    Industry Type:                             Department:  \
# 0                 Auto Components                    Finance & Accounting
# 2           Management Consulting             Engineering - Software & QA
# 3                         Banking            Sales & Business Development
# ...

# %%
for i in ['Role:','Industry Type:','Department:','Employment Type:','Role Category:']:
    details[i] = details[i].str.replace(',','')

# %%
details.isna().sum()
# Out:
# details_id          0
# Role:               0
# Industry Type:      0
# Department:         0
# Employment Type:    0
# Role Category:      0
# description         0
# skills_required     0
# dtype: int64

# %%
details.dropna(inplace = True)

# %%
sum(details.duplicated())
# Out:
# 0

# %%
details['Employment Type:'].unique()
# Out:
# array(['Full Time Permanent', 'Full Time Temporary/Contractual',
#        'Part Time Permanent', 'Part Time Temporary/Contractual',
#        'Part Time Freelance/Homebased'], dtype=object)

# %%
company
# Out:
#       company_id      company_name        founded_year india_employee_count  \
# 0          19589              Ford  1903 (120 yrs old)               5k-10k
# 1           7682         Accenture   1989 (34 yrs old)              1 Lakh+
# 2        4571516  Thrive Info Tech                 NaN                  NaN
# 3        1295512   Muthoot Finance   1939 (84 yrs old)              10k-50k
# 4        1295512   Muthoot Finance   1939 (84 yrs old)              10k-50k
# ...          ...               ...                 ...                  ...
# 1975        7682         Accenture   1989 (34 yrs old)              1 Lakh+
# 1976        7682         Accenture   1989 (34 yrs old)              1 Lakh+
# 1977        7682         Accenture   1989 (34 yrs old)              1 Lakh+
# 1978        7682         Accenture   1989 (34 yrs old)              1 Lakh+
# 1979        7682         Accenture   1989 (34 yrs old)              1 Lakh+
#
#      global_employee_count
# 0                  1 Lakh+
# ...

# %%
sum(company.duplicated())
# Out:
# 1690

# %%
company.drop_duplicates(inplace = True)

# %%
sum(company.duplicated())
# Out:
# 0

# %%
company
# Out:
#       company_id             company_name founded_year india_employee_count  \
# 0          19589                     Ford         1903               5k-10k
# 1           7682                Accenture         1989              1 Lakh+
# 2        4571516         Thrive Info Tech          NaN                  NaN
# 3        1295512          Muthoot Finance         1939              10k-50k
# 5            649                Capgemini         1967              1 Lakh+
# ...          ...                      ...          ...                  ...
# 1929     6383810         M/S One Kee Co .          NaN                  NaN
# 1931     1119552     Tech Mahindra Cerium          NaN                  NaN
# 1932      196760      Concentrix Catalyst         1983                  NaN
# 1933      234718                    Intel         1968              10k-50k
# 1949   123942507  Greenapp Infotech (opc)          NaN                  NaN
#
#      global_employee_count
# 0                  1 Lakh+
# ...

# %%
company.isna().sum()
# Out:
# company_id                 0
# company_name               0
# founded_year             123
# india_employee_count     127
# global_employee_count    156
# dtype: int64

# %%
company['founded_year'] = company['founded_year'].str[:4]

# %%
jobs.to_csv('jobs.csv', index=False)
details.to_csv('details.csv', index=False)
company.to_csv('company.csv', index=False)

# %%
file_path = 'C:/Users/abc/Downloads/jobs.csv'

# %%
jobs.to_csv(file_path, index=False)

# %%
file_path2 = 'C:/Users/abc/Downloads/details.csv'
details.to_csv(file_path2, index=False)

# %%
file_path3 = 'C:/Users/abc/Downloads/company.csv'
company.to_csv(file_path3, index=False)
